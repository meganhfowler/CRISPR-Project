# %%
import pandas as pd
import numpy as np

# %%
raw_data = pd.read_csv("raw_data/100720.csv")

# %% [markdown]
# ### Data Observations

# %% [markdown]
# ##### More than half the dataset is from the NucleaSeq Finkelstein experiments
# ##### Finkelstein experiments do not contain cell line or chromosome due to being in vitro
# ##### Finkelstein experiments do not contain target_context
# ##### Sequences are variable lengths
# ##### target_sequence ranges in length 20-25 nt
# ##### grna_target_sequence ranges in length 22-24 nt
# ##### 75 pairs which do not have a cleavage frequency
# ##### Length of grna != length of target for some pairs

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ##### Remove cell line, chromosome, target context, geneid since it is not available for over half the data

# %%
data = raw_data.drop([
    "target_chr", 
    "target_start", 
    "target_end", 
    "target_context", 
    "target_geneid", 
    "grna_target_chr", 
    "grna_target_start", 
    "grna_target_end",
    "genome",
    "cell_line"], axis = 1)
data
# Out:
#           id target_strand          target_sequence grna_target_strand  \
# 0          0             +  CTTGCCCCACAGGGCAGTAACGG                  +
# 1          1             -  CTCTGTCTCGCGCTGCTTTTGGG                  +
# 2          2             +  TCTACCCCACATGGCAGTAATGG                  +
# 3          3             +  CCATAGCACTCTTTAAAAAAAGC                  +
# 4          4             +  CTTACCTCACAGGGCAGTGAGAG                  +
# ...      ...           ...                      ...                ...
# 25627  25627             +  GTGATAAGTGGAATGCCATGTGT                  +
# 25628  25628             +  GTGATAAGTGGAATGCCATGTTA                  +
# 25629  25629             +  GTGATAAGTGGAATGCCATGTTC                  +
# 25630  25630             +  GTGATAAGTGGAATGCCATGTTG                  +
# 25631  25631             +  GTGATAAGTGGAATGCCATGTTT                  +
#
#           grna_target_sequence  cleavage_freq  epigen_ctcf  epigen_dnase  \
# 0      CTTGCCCCACAGGGCAGTAACGG   7.875890e-01          0.0           0.0
# 1      CTTGCCCCACAGGGCAGTAACGG   3.840000e-04          0.0           0.0
# 2      CTTGCCCCACAGGGCAGTAACGG   3.050000e-04          0.0           0.0
# 3      CTTGCCCCACAGGGCAGTAACGG   0.000000e+00          0.0           0.0
# 4      CTTGCCCCACAGGGCAGTAACGG   4.800000e-05          0.0           0.0
# ...                        ...            ...          ...           ...
# 25627  GTGATAAGTGGAATGCCATGTGG   9.614866e-20          0.0           0.0
# 25628  GTGATAAGTGGAATGCCATGTGG   5.104533e-17          0.0           0.0
# 25629  GTGATAAGTGGAATGCCATGTGG   1.125790e-19          0.0           0.0
# 25630  GTGATAAGTGGAATGCCATGTGG   7.712115e-06          0.0           0.0
# 25631  GTGATAAGTGGAATGCCATGTGG   1.490279e-22          0.0           0.0
#
#        epigen_rrbs  epigen_h3k4me3  epigen_drip  energy_1   energy_2  \
# 0              0.0             0.0          0.0    22.650  20.146794
# 1              0.0             0.0          0.0   -17.665 -51.262216
# 2              0.0             0.0          0.0    13.760   6.245204
# 3              0.0             0.0          0.0   -19.275   0.000000
# 4              0.0             0.0          0.0    11.610   2.751414
# ...            ...             ...          ...       ...        ...
# 25627          0.0             0.0          0.0    24.400   0.000000
# 25628          0.0             0.0          0.0    24.400   0.000000
# 25629          0.0             0.0          0.0    24.400   0.000000
# 25630          0.0             0.0          0.0    24.400   0.000000
# 25631          0.0             0.0          0.0    24.400   0.000000
#
#         energy_3  energy_4  energy_5   study_name  whole_genome  delivery_mode
# 0      20.146794    31.050    31.050          Kim             0              2
# 1     -51.262216    -9.265    -9.265          Kim             0              2
# 2       6.245204    22.160    22.160          Kim             0              2
# 3     -46.939290     0.000   -10.875          Kim             0              2
# 4       3.057127    18.009    20.010          Kim             0              2
# ...          ...       ...       ...          ...           ...            ...
# 25627  18.270788     0.000    26.900  Finkelstein             0              2
# 25628  18.270788     0.000    26.900  Finkelstein             0              2
# 25629  18.270788     0.000    26.900  Finkelstein             0              2
# 25630  18.270788     0.000    26.900  Finkelstein             0              2
# 25631  18.270788     0.000    26.900  Finkelstein             0              2
#
# [25632 rows x 19 columns]

# %% [markdown]
# ### Data Selection

# %% [markdown]
# ##### Version 1
# ##### Parameters: gRNA sequence, target sequence

# %%
data = data[["grna_target_sequence", "target_sequence", "cleavage_freq"]]
data = data.convert_dtypes()

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# ##### Version 1
# ##### No data augmentation

# %% [markdown]
# ### Data Padding

# %% [markdown]
# ##### Version 1
# ##### Padding: Pad end of each sequence out to 50 with X

# %%
data["grna_target_sequence"] = data["grna_target_sequence"].str.pad(width=50, side='right', fillchar='X')
data["target_sequence"] = data["target_sequence"].str.pad(width=50, side='right', fillchar='X')
data
# Out:
#                                     grna_target_sequence  \
# 0      CTTGCCCCACAGGGCAGTAACGGXXXXXXXXXXXXXXXXXXXXXXX...
# 1      CTTGCCCCACAGGGCAGTAACGGXXXXXXXXXXXXXXXXXXXXXXX...
# 2      CTTGCCCCACAGGGCAGTAACGGXXXXXXXXXXXXXXXXXXXXXXX...
# 3      CTTGCCCCACAGGGCAGTAACGGXXXXXXXXXXXXXXXXXXXXXXX...
# 4      CTTGCCCCACAGGGCAGTAACGGXXXXXXXXXXXXXXXXXXXXXXX...
# ...                                                  ...
# 25627  GTGATAAGTGGAATGCCATGTGGXXXXXXXXXXXXXXXXXXXXXXX...
# 25628  GTGATAAGTGGAATGCCATGTGGXXXXXXXXXXXXXXXXXXXXXXX...
# 25629  GTGATAAGTGGAATGCCATGTGGXXXXXXXXXXXXXXXXXXXXXXX...
# 25630  GTGATAAGTGGAATGCCATGTGGXXXXXXXXXXXXXXXXXXXXXXX...
# 25631  GTGATAAGTGGAATGCCATGTGGXXXXXXXXXXXXXXXXXXXXXXX...
#
#                                          target_sequence  cleavage_freq
# 0      CTTGCCCCACAGGGCAGTAACGGXXXXXXXXXXXXXXXXXXXXXXX...   7.875890e-01
# 1      CTCTGTCTCGCGCTGCTTTTGGGXXXXXXXXXXXXXXXXXXXXXXX...   3.840000e-04
# 2      TCTACCCCACATGGCAGTAATGGXXXXXXXXXXXXXXXXXXXXXXX...   3.050000e-04
# 3      CCATAGCACTCTTTAAAAAAAGCXXXXXXXXXXXXXXXXXXXXXXX...   0.000000e+00
# 4      CTTACCTCACAGGGCAGTGAGAGXXXXXXXXXXXXXXXXXXXXXXX...   4.800000e-05
# ...                                                  ...            ...
# 25627  GTGATAAGTGGAATGCCATGTGTXXXXXXXXXXXXXXXXXXXXXXX...   9.614866e-20
# 25628  GTGATAAGTGGAATGCCATGTTAXXXXXXXXXXXXXXXXXXXXXXX...   5.104533e-17
# 25629  GTGATAAGTGGAATGCCATGTTCXXXXXXXXXXXXXXXXXXXXXXX...   1.125790e-19
# 25630  GTGATAAGTGGAATGCCATGTTGXXXXXXXXXXXXXXXXXXXXXXX...   7.712115e-06
# 25631  GTGATAAGTGGAATGCCATGTTTXXXXXXXXXXXXXXXXXXXXXXX...   1.490279e-22
#
# [25632 rows x 3 columns]

# %% [markdown]
# ### Data Encoding

# %% [markdown]
# ##### Version 1
# ##### Sequential Encoding: X->0, A->0.25, T->0.5, G->0.75, C->1.0

# %%
class Encoding:
    def encode_nt(nt: str) -> int:
        assert len(nt) == 1
        encoding_dict = {
            'X':0, 
            'A':0.25,
            'T':0.50,
            'G':0.75,
            'C':1.00
        }
        return encoding_dict.get(nt.upper())
    
    def encode_seq(seq: str):
        encoding = [
            Encoding.encode_nt(nt)
            for nt in seq
        ]
        return np.array(encoding)
    
    def encode_seqs(sequence_array):
        encoded_sequences = [
            Encoding.encode_seq(seq)
            for seq in sequence_array
        ]
        return encoded_sequences

# %%
data["grna_target_sequence"] = Encoding.encode_seqs(data["grna_target_sequence"])
data["target_sequence"] = Encoding.encode_seqs(data["target_sequence"])
data
# Out:
#                                     grna_target_sequence  \
# 0      [1.0, 0.5, 0.5, 0.75, 1.0, 1.0, 1.0, 1.0, 0.25...
# 1      [1.0, 0.5, 0.5, 0.75, 1.0, 1.0, 1.0, 1.0, 0.25...
# 2      [1.0, 0.5, 0.5, 0.75, 1.0, 1.0, 1.0, 1.0, 0.25...
# 3      [1.0, 0.5, 0.5, 0.75, 1.0, 1.0, 1.0, 1.0, 0.25...
# 4      [1.0, 0.5, 0.5, 0.75, 1.0, 1.0, 1.0, 1.0, 0.25...
# ...                                                  ...
# 25627  [0.75, 0.5, 0.75, 0.25, 0.5, 0.25, 0.25, 0.75,...
# 25628  [0.75, 0.5, 0.75, 0.25, 0.5, 0.25, 0.25, 0.75,...
# 25629  [0.75, 0.5, 0.75, 0.25, 0.5, 0.25, 0.25, 0.75,...
# 25630  [0.75, 0.5, 0.75, 0.25, 0.5, 0.25, 0.25, 0.75,...
# 25631  [0.75, 0.5, 0.75, 0.25, 0.5, 0.25, 0.25, 0.75,...
#
#                                          target_sequence  cleavage_freq
# 0      [1.0, 0.5, 0.5, 0.75, 1.0, 1.0, 1.0, 1.0, 0.25...   7.875890e-01
# 1      [1.0, 0.5, 1.0, 0.5, 0.75, 0.5, 1.0, 0.5, 1.0,...   3.840000e-04
# 2      [0.5, 1.0, 0.5, 0.25, 1.0, 1.0, 1.0, 1.0, 0.25...   3.050000e-04
# 3      [1.0, 1.0, 0.25, 0.5, 0.25, 0.75, 1.0, 0.25, 1...   0.000000e+00
# 4      [1.0, 0.5, 0.5, 0.25, 1.0, 1.0, 0.5, 1.0, 0.25...   4.800000e-05
# ...                                                  ...            ...
# 25627  [0.75, 0.5, 0.75, 0.25, 0.5, 0.25, 0.25, 0.75,...   9.614866e-20
# 25628  [0.75, 0.5, 0.75, 0.25, 0.5, 0.25, 0.25, 0.75,...   5.104533e-17
# 25629  [0.75, 0.5, 0.75, 0.25, 0.5, 0.25, 0.25, 0.75,...   1.125790e-19
# 25630  [0.75, 0.5, 0.75, 0.25, 0.5, 0.25, 0.25, 0.75,...   7.712115e-06
# 25631  [0.75, 0.5, 0.75, 0.25, 0.5, 0.25, 0.25, 0.75,...   1.490279e-22
#
# [25632 rows x 3 columns]
