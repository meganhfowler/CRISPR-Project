# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
preds1 = pd.read_csv("../results/predictions/model1.csv")
preds1 = preds1[["cleavage_freq", "predictions"]]
preds1
# Out:
#       cleavage_freq  predictions
# 0      1.617078e-03     0.254784
# 1      1.000000e-04     0.093071
# 2      3.620000e-04    -0.053028
# 3     -2.000000e-06     0.084296
# 4      1.881533e-03     0.050296
# ...             ...          ...
# 5099   1.958496e-04     0.029060
# 5100   4.300000e-05     0.021965
# 5101   6.437991e-20     0.007226
# 5102   5.266276e-03     0.008312
# 5103   3.662994e-19     0.054459
#
# [5104 rows x 2 columns]

# %%
fig = plt.figure(figsize = (9, 9))
plt.scatter(preds1["cleavage_freq"], preds1["predictions"])
plt.title("Model 1 Predictions")
plt.xlabel("Actual cleavage frequency")
plt.ylabel("Predicted cleavage frequency")
fig.savefig("/mnt/c/Users/Megan/Documents/School/SFU/CMPT 415/preds1.png")

# %%
preds2 = pd.read_csv("../results/predictions/model2.csv")
preds2 = preds1[["cleavage_freq", "predictions"]]
fig = plt.figure(figsize = (9, 9))
plt.scatter(preds2["cleavage_freq"], preds2["predictions"])
plt.title("Model 2 Predictions")
plt.xlabel("Actual cleavage frequency")
plt.ylabel("Predicted cleavage frequency")
fig.savefig("/mnt/c/Users/Megan/Documents/School/SFU/CMPT 415/preds2.png")

# %%
'mean_squared_error': 0.041616052, 'spearman_rank': {'correlation': 0.14000553915922814,
'mean_squared_error': 0.042410064, 'spearman_rank': {'correlation': 0.1893224973229979
# Out:
#   File "<ipython-input-6-4147f9a8f524>", line 1
#     'mean_squared_error': 0.041616052, 'spearman_rank': {'correlation': 0.14000553915922814,
#                                      ^
# SyntaxError: invalid syntax

# %%
actual = pd.read_csv("../data/train.csv")

actual["cleavage_freq"].describe()
# Out:
# count    20450.000000
# mean         0.036272
# std          0.194327
# min         -0.001531
# 25%          0.000040
# 50%          0.000200
# 75%          0.001872
# max          3.295642
# Name: cleavage_freq, dtype: float64

# %%
preds1["predictions"].describe()
# Out:
# count    5104.000000
# mean        0.029749
# std         0.052896
# min        -0.164539
# 25%        -0.001949
# 50%         0.025983
# 75%         0.058807
# max         0.291247
# Name: predictions, dtype: float64

# %%
preds2["predictions"].describe()
# Out:
# count    5104.000000
# mean        0.029749
# std         0.052896
# min        -0.164539
# 25%        -0.001949
# 50%         0.025983
# 75%         0.058807
# max         0.291247
# Name: predictions, dtype: float64
